# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre= "Terminator"
año= 1985
visto= True
print(f"Nombre: {nombre}, Año: {año}, Visto: {visto}")
# Out:
# Nombre: terminator, Año: 1984, Visto: True

# %%
peliculas= [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]
años=[
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001]
vistas=[
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]   
index = 0
while index < len(peliculas):
    print(f"Película: {peliculas[index]}, Año: {años[index]}, Visto: {vistas[index]}")
    index += 1
# Out:
# Película: The Shawshank Redemption, Año: 1994, Visto: True
# Película: The Dark Knight, Año: 2008, Visto: False
# Película: Inception, Año: 2010, Visto: True
# Película: Pulp Fiction, Año: 1994, Visto: False
# Película: The Matrix, Año: 1999, Visto: True
# Película: Interstellar, Año: 2014, Visto: False
# Película: Parasite, Año: 2019, Visto: True
# Película: Gladiator, Año: 2000, Visto: False
# Película: Titanic, Año: 1997, Visto: True
# Película: The Lord of the Rings: The Fellowship of the Ring, Año: 2001, Visto: False
